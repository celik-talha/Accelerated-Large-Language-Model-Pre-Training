# %%
from google.colab import drive
drive.mount('/content/drive')
import os

# !git clone https://github.com/arcee-ai/mergekit.git
# %cd mergekit
# !pip install -e .

# %%
model_path = "/content/drive/MyDrive/Bitirme/Models/MetaMath/llama-1b-base-metamath"
merge_path = "/content/drive/MyDrive/Bitirme/Models/Merged/MetaMath/llama-1b-base-metamath-slerp"
final_path = "/content/drive/MyDrive/Bitirme/Models/Final/MetaMath/llama-1b-base-metamath-slerp"

# %%
# !mergekit-yaml config1a.yaml {merge_path}-1.a --cuda
# !mergekit-yaml config1b.yaml {merge_path}-1.b --cuda
# !mergekit-yaml config2a.yaml {merge_path}-2.a --cuda
# !mergekit-yaml config2b.yaml {merge_path}-2.b --cuda
# !mergekit-yaml config3a.yaml {merge_path}-3.a --cuda
# !mergekit-yaml config3b.yaml {merge_path}-3.b --cuda
# !mergekit-yaml config4a.yaml {merge_path}-4.a --cuda
# !mergekit-yaml config4b.yaml {merge_path}-4.b --cuda
# !mergekit-yaml config5a.yaml {merge_path}-5.a --cuda
# !mergekit-yaml config5b.yaml {merge_path}-5.b --cuda
# !mergekit-yaml config6a.yaml {merge_path}-6.a --cuda
# !mergekit-yaml config6b.yaml {merge_path}-6.b --cuda
# !mergekit-yaml config7a.yaml {merge_path}-7.a --cuda
# !mergekit-yaml config7b.yaml {merge_path}-7.b --cuda
# !mergekit-yaml config8a.yaml {merge_path}-8.a --cuda
# !mergekit-yaml config8b.yaml {merge_path}-8.b --cuda
# !mergekit-yaml config9a.yaml {merge_path}-9.a --cuda
# !mergekit-yaml config9b.yaml {merge_path}-9.b --cuda

# !mergekit-yaml config1.yaml {final_path}-1 --cuda
# !mergekit-yaml config2.yaml {final_path}-2 --cuda
# !mergekit-yaml config3.yaml {final_path}-3 --cuda
# !mergekit-yaml config4.yaml {final_path}-4 --cuda
# !mergekit-yaml config5.yaml {final_path}-5 --cuda
# !mergekit-yaml config6.yaml {final_path}-6 --cuda
# !mergekit-yaml config7.yaml {final_path}-7 --cuda
# !mergekit-yaml config8.yaml {final_path}-8 --cuda
# !mergekit-yaml config9.yaml {final_path}-9 --cuda

# %%
#SLERP 1a
yaml_config = f"""\
models:
  - model: {model_path}-1.1
    weight: 0.5
    file_type: safetensors
  - model: {model_path}-1.2
    weight: 0.5
    file_type: safetensors

merge_method: slerp
base_model: {model_path}-1.1
parameters:
  t: 0.5  # Default value

  per_layer_settings:  # List of ConditionalParameter objects
  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.0"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.1"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.2"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.3"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.4"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.5"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.6"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.7"  # Which layer(s) to match
    value: 0.8  # The override value

dtype: float16
"""

with open("config1a.yaml", "w") as f:
    f.write(yaml_config)

# %%
#SLERP 1b
yaml_config = f"""\
models:
  - model: {model_path}-1.3
    weight: 0.5
    file_type: safetensors
  - model: {model_path}-1.4
    weight: 0.5
    file_type: safetensors

merge_method: slerp
base_model: {model_path}-1.3
parameters:
  t: 0.5  # Default value

  per_layer_settings:  # List of ConditionalParameter objects
  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.8"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.9"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.10"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.11"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.12"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.13"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.14"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.15"  # Which layer(s) to match
    value: 0.8  # The override value

dtype: float16
"""

with open("config1b.yaml", "w") as f:
    f.write(yaml_config)

# %%
#SLERP 1
yaml_config = f"""\
models:
  - model: {merge_path}-1.a
    weight: 0.5
    file_type: safetensors
  - model: {merge_path}-1.b
    weight: 0.5
    file_type: safetensors

merge_method: slerp
base_model: {merge_path}-1.a
parameters:
  t: 0.5  # Default value

  per_layer_settings:  # List of ConditionalParameter objects
  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.0"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.1"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.2"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.3"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.4"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.5"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.6"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.7"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.8"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.9"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.10"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.11"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.12"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.13"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.14"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.15"  # Which layer(s) to match
    value: 0.8  # The override value

dtype: float16
"""

with open("config1.yaml", "w") as f:
    f.write(yaml_config)

# %%
#SLERP 2a
yaml_config = f"""\
models:
  - model: {model_path}-2.1
    weight: 0.5
    file_type: safetensors
  - model: {model_path}-2.2
    weight: 0.5
    file_type: safetensors

merge_method: slerp
base_model: {model_path}-2.1
parameters:
  t: 0.5  # Default value

dtype: float16
"""

with open("config2a.yaml", "w") as f:
    f.write(yaml_config)

# %%
#SLERP 2b
yaml_config = f"""\
models:
  - model: {model_path}-2.3
    weight: 0.5
    file_type: safetensors
  - model: {model_path}-2.4
    weight: 0.5
    file_type: safetensors

merge_method: slerp
base_model: {model_path}-2.3
parameters:
  t: 0.5  # Default value

dtype: float16
"""

with open("config2b.yaml", "w") as f:
    f.write(yaml_config)

# %%
#SLERP 2
yaml_config = f"""\
models:
  - model: {merge_path}-2.a
    weight: 0.5
    file_type: safetensors
  - model: {merge_path}-2.b
    weight: 0.5
    file_type: safetensors

merge_method: slerp
base_model: {merge_path}-2.a
parameters:
  t: 0.5  # Default value

  per_layer_settings:  # List of ConditionalParameter objects
  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.0"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.1"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.2"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.3"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.4"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.5"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.6"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.7"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.8"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.9"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.10"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.11"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.12"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.13"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.14"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.15"  # Which layer(s) to match
    value: 0.8  # The override value

dtype: float16
"""

with open("config2.yaml", "w") as f:
    f.write(yaml_config)

# %%
#SLERP 3a
yaml_config = f"""\
models:
  - model: {model_path}-3.1
    weight: 0.5
    file_type: safetensors
  - model: {model_path}-3.2
    weight: 0.5
    file_type: safetensors

merge_method: slerp
base_model: {model_path}-3.1
parameters:
  t: 0.5  # Default value

  per_layer_settings:  # List of ConditionalParameter objects
  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.0"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.1"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.2"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.6"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.7"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.8"  # Which layer(s) to match
    value: 0.8  # The override value

dtype: float16
"""

with open("config3a.yaml", "w") as f:
    f.write(yaml_config)

# %%
#SLERP 3b
yaml_config = f"""\
models:
  - model: {model_path}-3.3
    weight: 0.5
    file_type: safetensors
  - model: {model_path}-3.4
    weight: 0.5
    file_type: safetensors

merge_method: slerp
base_model: {model_path}-3.3
parameters:
  t: 0.5  # Default value

  per_layer_settings:  # List of ConditionalParameter objects
  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.6"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.7"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.8"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.8"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.13"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.14"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.15"  # Which layer(s) to match
    value: 0.8  # The override value

dtype: float16
"""

with open("config3b.yaml", "w") as f:
    f.write(yaml_config)

# %%
#SLERP 3
yaml_config = f"""\
models:
  - model: {merge_path}-3.a
    weight: 0.5
    file_type: safetensors
  - model: {merge_path}-3.b
    weight: 0.5
    file_type: safetensors

merge_method: slerp
base_model: {merge_path}-3.a
parameters:
  t: 0.5  # Default value

  per_layer_settings:  # List of ConditionalParameter objects
  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.0"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.1"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.2"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.3"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.4"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.5"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.9"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.10"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.11"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.12"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.13"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.14"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.15"  # Which layer(s) to match
    value: 0.8  # The override value

dtype: float16
"""

with open("config3.yaml", "w") as f:
    f.write(yaml_config)

# %%
#SLERP 4a
yaml_config = f"""\
models:
  - model: {model_path}-4.1
    weight: 0.5
    file_type: safetensors
  - model: {model_path}-4.2
    weight: 0.5
    file_type: safetensors

merge_method: slerp
base_model: {model_path}-4.1
parameters:
  t: 0.5  # Default value

dtype: float16
"""

with open("config4a.yaml", "w") as f:
    f.write(yaml_config)

# %%
#SLERP 4b
yaml_config = f"""\
models:
  - model: {model_path}-4.3
    weight: 0.5
    file_type: safetensors
  - model: {model_path}-4.4
    weight: 0.5
    file_type: safetensors

merge_method: slerp
base_model: {model_path}-4.3
parameters:
  t: 0.5  # Default value

dtype: float16
"""

with open("config4b.yaml", "w") as f:
    f.write(yaml_config)

# %%
#SLERP 4
yaml_config = f"""\
models:
  - model: {merge_path}-4.a
    weight: 0.5
    file_type: safetensors
  - model: {merge_path}-4.b
    weight: 0.5
    file_type: safetensors

merge_method: slerp
base_model: {merge_path}-4.a
parameters:
  t: 0.5  # Default value

dtype: float16
"""

with open("config4.yaml", "w") as f:
    f.write(yaml_config)

# %%
#SLERP 5a
yaml_config = f"""\
models:
  - model: {model_path}-5.1
    weight: 0.5
    file_type: safetensors
  - model: {model_path}-5.2
    weight: 0.5
    file_type: safetensors

merge_method: slerp
base_model: {model_path}-5.1
parameters:
  t: 0.5  # Default value

  per_layer_settings:  # List of ConditionalParameter objects
  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.4"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.5"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.6"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.7"  # Which layer(s) to match
    value: 0.8  # The override value

dtype: float16
"""

with open("config5a.yaml", "w") as f:
    f.write(yaml_config)

# %%
#SLERP 5a
yaml_config = f"""\
models:
  - model: {model_path}-1.1
    weight: 0.5
    file_type: safetensors
  - model: {model_path}-2.2
    weight: 0.5
    file_type: safetensors

merge_method: slerp
base_model: {model_path}-1.1
parameters:
  t: 0.5  # Default value

  per_layer_settings:  # List of ConditionalParameter objects
  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.4"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.5"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.6"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.7"  # Which layer(s) to match
    value: 0.8  # The override value

dtype: float16
"""

with open("config5a.yaml", "w") as f:
    f.write(yaml_config)

# %%
#SLERP 5b
yaml_config = f"""\
models:
  - model: {model_path}-5.3
    weight: 0.5
    file_type: safetensors
  - model: {model_path}-5.4
    weight: 0.5
    file_type: safetensors

merge_method: slerp
base_model: {model_path}-5.3
parameters:
  t: 0.5  # Default value

  per_layer_settings:  # List of ConditionalParameter objects
  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.12"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.13"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.14"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.15"  # Which layer(s) to match
    value: 0.8  # The override value

dtype: float16
"""

with open("config5b.yaml", "w") as f:
    f.write(yaml_config)

# %%
#SLERP 5b
yaml_config = f"""\
models:
  - model: {model_path}-2.3
    weight: 0.5
    file_type: safetensors
  - model: {model_path}-1.4
    weight: 0.5
    file_type: safetensors

merge_method: slerp
base_model: {model_path}-2.3
parameters:
  t: 0.5  # Default value

  per_layer_settings:  # List of ConditionalParameter objects
  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.12"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.13"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.14"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.15"  # Which layer(s) to match
    value: 0.8  # The override value

dtype: float16
"""

with open("config5b.yaml", "w") as f:
    f.write(yaml_config)

# %%
#SLERP 5
yaml_config = f"""\
models:
  - model: {merge_path}-5.a
    weight: 0.5
    file_type: safetensors
  - model: {merge_path}-5.b
    weight: 0.5
    file_type: safetensors

merge_method: slerp
base_model: {merge_path}-5.a
parameters:
  t: 0.5  # Default value

  per_layer_settings:  # List of ConditionalParameter objects
  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.0"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.1"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.2"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.3"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.4"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.5"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.6"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.7"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.8"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.9"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.10"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.11"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.12"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.13"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.14"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.15"  # Which layer(s) to match
    value: 0.8  # The override value

dtype: float16
"""

with open("config5.yaml", "w") as f:
    f.write(yaml_config)

# %%
#SLERP 6a
yaml_config = f"""\
models:
  - model: {model_path}-6.1
    weight: 0.5
    file_type: safetensors
  - model: {model_path}-6.2
    weight: 0.5
    file_type: safetensors

merge_method: slerp
base_model: {model_path}-6.1
parameters:
  t: 0.5  # Default value

  per_layer_settings:  # List of ConditionalParameter objects
  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.0"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.1"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.2"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.3"  # Which layer(s) to match
    value: 0.2  # The override value

dtype: float16
"""

with open("config6a.yaml", "w") as f:
    f.write(yaml_config)

# %%
#SLERP 6a
yaml_config = f"""\
models:
  - model: {model_path}-4.1
    weight: 0.5
    file_type: safetensors
  - model: {model_path}-6.2
    weight: 0.5
    file_type: safetensors

merge_method: slerp
base_model: {model_path}-4.1
parameters:
  t: 0.5  # Default value

  per_layer_settings:  # List of ConditionalParameter objects
  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.0"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.1"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.2"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.3"  # Which layer(s) to match
    value: 0.2  # The override value

dtype: float16
"""

with open("config6a.yaml", "w") as f:
    f.write(yaml_config)

# %%
#SLERP 6b
yaml_config = f"""\
models:
  - model: {model_path}-6.3
    weight: 0.5
    file_type: safetensors
  - model: {model_path}-6.4
    weight: 0.5
    file_type: safetensors

merge_method: slerp
base_model: {model_path}-6.3
parameters:
  t: 0.5  # Default value

  per_layer_settings:  # List of ConditionalParameter objects
  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.8"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.9"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.10"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.11"  # Which layer(s) to match
    value: 0.8  # The override value

dtype: float16
"""

with open("config6b.yaml", "w") as f:
    f.write(yaml_config)

# %%
#SLERP 6b
yaml_config = f"""\
models:
  - model: {model_path}-2.3
    weight: 0.5
    file_type: safetensors
  - model: {model_path}-1.4
    weight: 0.5
    file_type: safetensors

merge_method: slerp
base_model: {model_path}-2.3
parameters:
  t: 0.5  # Default value

  per_layer_settings:  # List of ConditionalParameter objects
  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.8"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.9"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.10"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.11"  # Which layer(s) to match
    value: 0.8  # The override value

dtype: float16
"""

with open("config6b.yaml", "w") as f:
    f.write(yaml_config)

# %%
#SLERP 6
yaml_config = f"""\
models:
  - model: {merge_path}-6.a
    weight: 0.5
    file_type: safetensors
  - model: {merge_path}-6.b
    weight: 0.5
    file_type: safetensors

merge_method: slerp
base_model: {merge_path}-6.a
parameters:
  t: 0.5  # Default value

  per_layer_settings:  # List of ConditionalParameter objects
  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.0"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.1"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.2"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.3"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.4"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.5"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.6"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.7"  # Which layer(s) to match
    value: 0.2  # The override value


dtype: float16
"""

with open("config6.yaml", "w") as f:
    f.write(yaml_config)

# %%
#SLERP 7a
yaml_config = f"""\
models:
  - model: {model_path}-7.1
    weight: 0.5
    file_type: safetensors
  - model: {model_path}-7.2
    weight: 0.5
    file_type: safetensors

merge_method: slerp
base_model: {model_path}-7.1
parameters:
  t: 0.5  # Default value

  per_layer_settings:  # List of ConditionalParameter objects
  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.0"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.1"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.2"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.3"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.4"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.5"  # Which layer(s) to match
    value: 0.2  # The override value

dtype: float16
"""

with open("config7a.yaml", "w") as f:
    f.write(yaml_config)

# %%
#SLERP 7b
yaml_config = f"""\
models:
  - model: {model_path}-7.3
    weight: 0.5
    file_type: safetensors
  - model: {model_path}-7.4
    weight: 0.5
    file_type: safetensors

merge_method: slerp
base_model: {model_path}-7.3
parameters:
  t: 0.5  # Default value

  per_layer_settings:  # List of ConditionalParameter objects
  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.4"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.5"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.6"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.7"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.8"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.9"  # Which layer(s) to match
    value: 0.8  # The override value

dtype: float16
"""

with open("config7b.yaml", "w") as f:
    f.write(yaml_config)

# %%
#SLERP 7
yaml_config = f"""\
models:
  - model: {merge_path}-7.a
    weight: 0.5
    file_type: safetensors
  - model: {merge_path}-7.b
    weight: 0.5
    file_type: safetensors

merge_method: slerp
base_model: {merge_path}-7.a
parameters:
  t: 0.5  # Default value

  per_layer_settings:  # List of ConditionalParameter objects
  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.0"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.1"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.2"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.3"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.12"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.13"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.14"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.15"  # Which layer(s) to match
    value: 0.8  # The override value


dtype: float16
"""

with open("config7.yaml", "w") as f:
    f.write(yaml_config)

# %%
#SLERP 8a
yaml_config = f"""\
models:
  - model: {model_path}-8.1
    weight: 0.5
    file_type: safetensors
  - model: {model_path}-8.2
    weight: 0.5
    file_type: safetensors

merge_method: slerp
base_model: {model_path}-8.1
parameters:
  t: 0.5  # Default value

  per_layer_settings:  # List of ConditionalParameter objects
  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.0"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.1"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.2"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.3"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.4"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.5"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.6"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.7"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.8"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.9"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.10"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.11"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.12"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.13"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.14"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.15"  # Which layer(s) to match
    value: 0.8  # The override value

dtype: float16
"""

with open("config8a.yaml", "w") as f:
    f.write(yaml_config)

# %%
#SLERP 8a
yaml_config = f"""\
models:
  - model: {model_path}-1.1
    weight: 0.5
    file_type: safetensors
  - model: {model_path}-6.2
    weight: 0.5
    file_type: safetensors

merge_method: slerp
base_model: {model_path}-1.1
parameters:
  t: 0.5  # Default value

  per_layer_settings:  # List of ConditionalParameter objects
  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.0"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.1"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.2"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.3"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.4"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.5"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.6"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.7"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.8"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.9"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.10"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.11"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.12"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.13"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.14"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.15"  # Which layer(s) to match
    value: 0.8  # The override value

dtype: float16
"""

with open("config8a.yaml", "w") as f:
    f.write(yaml_config)

# %%
#SLERP 8b
yaml_config = f"""\
models:
  - model: {model_path}-8.3
    weight: 0.5
    file_type: safetensors
  - model: {model_path}-8.4
    weight: 0.5
    file_type: safetensors

merge_method: slerp
base_model: {model_path}-8.3
parameters:
  t: 0.5  # Default value

dtype: float16
"""

with open("config8b.yaml", "w") as f:
    f.write(yaml_config)

# %%
#SLERP 8b
yaml_config = f"""\
models:
  - model: {model_path}-8.3
    weight: 0.5
    file_type: safetensors
  - model: {model_path}-7.4
    weight: 0.5
    file_type: safetensors

merge_method: slerp
base_model: {model_path}-8.3
parameters:
  t: 0.5  # Default value

dtype: float16
"""

with open("config8b.yaml", "w") as f:
    f.write(yaml_config)

# %%
#SLERP 8
yaml_config = f"""\
models:
  - model: {merge_path}-8.a
    weight: 0.5
    file_type: safetensors
  - model: {merge_path}-8.b
    weight: 0.5
    file_type: safetensors

merge_method: slerp
base_model: {merge_path}-8.a
parameters:
  t: 0.5  # Default value

  per_layer_settings:  # List of ConditionalParameter objects
  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.0"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.1"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.2"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.3"  # Which layer(s) to match
    value: 0.2  # The override value

dtype: float16
"""

with open("config8.yaml", "w") as f:
    f.write(yaml_config)

# %%
#SLERP 9a
yaml_config = f"""\
models:
  - model: {model_path}-9.1
    weight: 0.5
    file_type: safetensors
  - model: {model_path}-9.2
    weight: 0.5
    file_type: safetensors

merge_method: slerp
base_model: {model_path}-9.1
parameters:
  t: 0.5  # Default value

  per_layer_settings:  # List of ConditionalParameter objects
  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.0"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.1"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.2"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.3"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.4"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.5"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.6"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.7"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.8"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.9"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.10"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.11"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.12"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.13"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.14"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.15"  # Which layer(s) to match
    value: 0.8  # The override value

dtype: float16
"""

with open("config9a.yaml", "w") as f:
    f.write(yaml_config)

# %%
#SLERP 9a
yaml_config = f"""\
models:
  - model: {model_path}-7.1
    weight: 0.5
    file_type: safetensors
  - model: {model_path}-9.2
    weight: 0.5
    file_type: safetensors

merge_method: slerp
base_model: {model_path}-7.1
parameters:
  t: 0.5  # Default value

  per_layer_settings:  # List of ConditionalParameter objects
  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.0"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.1"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.2"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.3"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.4"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.5"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.6"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.7"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.8"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.9"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.10"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.11"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.12"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.13"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.14"  # Which layer(s) to match
    value: 0.8  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.15"  # Which layer(s) to match
    value: 0.8  # The override value

dtype: float16
"""

with open("config9a.yaml", "w") as f:
    f.write(yaml_config)

# %%
#SLERP 9b
yaml_config = f"""\
models:
  - model: {model_path}-9.3
    weight: 0.5
    file_type: safetensors
  - model: {model_path}-9.4
    weight: 0.5
    file_type: safetensors

merge_method: slerp
base_model: {model_path}-9.3
parameters:
  t: 0.5  # Default value

dtype: float16
"""

with open("config9b.yaml", "w") as f:
    f.write(yaml_config)

# %%
#SLERP 9b
yaml_config = f"""\
models:
  - model: {model_path}-9.3
    weight: 0.5
    file_type: safetensors
  - model: {model_path}-1.4
    weight: 0.5
    file_type: safetensors

merge_method: slerp
base_model: {model_path}-9.3
parameters:
  t: 0.5  # Default value

dtype: float16
"""

with open("config9b.yaml", "w") as f:
    f.write(yaml_config)

# %%
#SLERP 9
yaml_config = f"""\
models:
  - model: {merge_path}-9.a
    weight: 0.5
    file_type: safetensors
  - model: {merge_path}-9.b
    weight: 0.5
    file_type: safetensors

merge_method: slerp
base_model: {merge_path}-9.a
parameters:
  t: 0.5  # Default value

  per_layer_settings:  # List of ConditionalParameter objects
  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.0"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.1"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.2"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.3"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.4"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.5"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.6"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.7"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.8"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.9"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.10"  # Which layer(s) to match
    value: 0.2  # The override value

  - parameter: t  # Which parameter this overrides
    layer_pattern: "model.layers.11"  # Which layer(s) to match
    value: 0.2  # The override value

dtype: float16
"""

with open("config9.yaml", "w") as f:
    f.write(yaml_config)
